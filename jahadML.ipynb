# %%
# !pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.2.6-cp313-cp313-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.5 MB 750.7 kB/s eta 0:00:15
#    - -------------------------------------- 0.5/11.5 MB 750.7 kB/s eta 0:00:15
#    - -------------------------------------- 0.5/11.5 MB 750.7 kB/s eta 0:00:15
#    - -------------------------------------- 0.5/11.5 MB 750.7 kB/s eta 0:00:15
# ...

# %%
import pandas as pd

# %%
dataset=pd.read_csv('C:/Users/FA/Desktop/heart.csv')

# %%
dataset
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
features=dataset.iloc[:, :-1]
labels=dataset.iloc[:,-1]

# %%
labels
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1020    1
# 1021    0
# 1022    0
# 1023    1
# 1024    0
# Name: target, Length: 1025, dtype: int64

# %%
from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from sklearn.model_selection import train_test_split
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# !pip install scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.1 MB ? eta -:--:--
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_tr,x_ts,y_tr,y_ts = train_test_split(features,labels,test_size=0.2)

# %%
x_ts
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 367   48    1   1       110   229    0        1      168      0      1.0
# 315   42    1   3       148   244    0        0      178      0      0.8
# 454   65    0   0       150   225    0        0      114      0      1.0
# 382   59    1   0       110   239    0        0      142      1      1.2
# 704   51    1   2        94   227    0        1      154      1      0.0
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 851   37    1   2       130   250    0        1      187      0      3.5
# 506   61    1   0       120   260    0        1      140      1      3.6
# 492   64    1   2       125   309    0        1      131      1      1.8
# 836   53    0   0       138   234    0        0      160      0      0.0
# 600   62    0   2       130   263    0        1       97      0      1.2
#
#      slope  ca  thal
# 367      0   0     3
# 315      2   2     2
# 454      1   3     3
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.metrics import confusion_matrix,accuracy_score

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(x_tr,y_tr)
knn_pred = knn.predict(x_ts)
print(accuracy_score(knn_pred,y_ts))
print(confusion_matrix(y_ts,knn_pred))
# Out:
# 0.9560975609756097
# [[107   4]
#  [  5  89]]
